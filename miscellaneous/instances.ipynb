# %%
from src.functions import *

# %%
n_random_intances = 100

# %%
h = {}
J = {}
for n in range(2,21):
    h[n] = [generate_random_h(n, seed=i).tolist() for i in range(n_random_intances)]
    J[n] = [generate_random_J(n, seed=i).tolist() for i in range(n_random_intances)]
