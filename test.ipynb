# %%
from src.functions import *

# %%
num_models = 10000
n = 5

E = []

for i in range(num_models):
    m = RandomIsingModel(n, seed=i)
    E.append(m.E[10])

print(f'mean: {np.mean(E)}, std: {np.std(E)}')
# Out:
# mean: -0.002779773925159893, std: 3.8432444924007636

# %%
np.mean(E)
# Out:
# -0.02968701172847428

# %%
# print(RandomIsingModel(n, seed=0))

# %%
print(RandomIsingModel(n, seed=1))
# Out:
# Ising model information:
# Number of spins: 3
# External fields (h): [ 1.62434536 -0.61175641 -0.52817175]
# Interaction matrix (J):
# [[ 0.         -0.61175641 -0.52817175]
#  [-0.61175641  0.         -2.3015387 ]
#  [-0.52817175 -2.3015387   0.        ]]
# Alpha: 0.5697411990438161
# Ground state energy: -4.0930533833167635
# Ground state: |010> = |2>
# Ground state degeneracy: 1
# Energy spectrum: [ 2.95704967 -3.75871474 -4.09305338 -1.602663    3.92588406 -0.67719333
#  -0.67719333  3.92588406]

# %%
counts, bins = np.histogram(E)
plt.stairs(counts, bins)
