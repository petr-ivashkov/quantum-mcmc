# %%
from functions import *

# %%
m = RandomIsingModel(4)
T = 2
mat = get_proposal_mat_local(m)

# %%
P = get_transition_matrix(m, T, mat)

# %%
samples = get_trajectory(P, 100)

# %%
plt.plot(samples)
